# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 10.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8l.pt data='/content/drive/MyDrive/ASE Project/Datasets/Object Detection Dataset for ASE Project/Cotton plant disease prediction/data.yaml' epochs=10 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 135MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
